# %% [markdown]
# #### References
# * https://www.sbert.net/examples/applications/image-search/README.html

# %%
from nltk.tokenize import sent_tokenize
import pandas as pd
from typing import Union
import pdfplumber
import fitz
import glob, sys
import os
from glob import glob
import re
from collections import OrderedDict
import requests
import pickle
from pdf2image import convert_from_path
from pdf2image import convert_from_bytes

# %%
pdf_folder_path = f'../data/genai_poc/'
os.listdir(pdf_folder_path)
# Out:
# ['processed', 'raw', '.ipynb_checkpoints']

# %% [markdown]
# ##### Challanges
# * If a section is continuing in next page
# * Parsed data layout orientation is not always fully correct
# * Topic distributed accross different table of content items

# %%
class pymupdf_extraction_utils():
    
    def __init__(self,pdf_path = None):
        self.set_header_type = None
        self.pdf_data_path = pdf_path
        self.doc = self.read_pdf()
        
    def read_pdf(self):
        '''
        Read PDF using Langchain Unstructured PDF Loader api
        '''
        return fitz.open(self.pdf_data_path)
    
    def save_page_images_old(self, image_fold_path = None):
        zoom_x = 1.0  # horizontal zoom
        zoom_y = 1.0  # vertical zoom
        mat = fitz.Matrix(zoom_x, zoom_y)  # zoom factor 2 in each dimension
        
        if image_fold_path is not None:
            image_path = image_fold_path
        else:
            image_path = os.path.dirname(os.path.abspath(self.pdf_data_path))+'/out'
            
        fold = os.path.basename(self.pdf_data_path).replace('.pdf','')
        
        fold_path = os.path.join(image_path, fold)
        
        if not os.path.exists(fold_path):
            os.makedirs(fold_path)
        
        if len(glob(fold_path+'/*.jpg')) == 0:
            print("Converting Pages in Images...")
            for page in self.doc:  # iterate through the pages
                pix = page.get_pixmap(matrix=mat)  # render page to an image
                pix.save("%s/page-%i.jpg"%(fold_path, page.number))
        return fold_path
    
    def save_page_images(self, image_fold_path = None):
        
        if image_fold_path is not None:
            image_path = image_fold_path
        else:
            image_path = os.path.dirname(os.path.abspath(self.pdf_data_path))+'/out'
            
        fold = os.path.basename(self.pdf_data_path).replace('.pdf','')
        
        fold_path = os.path.join(image_path, fold)
        
        if not os.path.exists(fold_path):
            os.makedirs(fold_path)
        
        if len(glob(fold_path+'/*.jpg')) == 0:
            print("Converting Pages in Images...")
            pdf_im_data = convert_from_path(self.pdf_data_path)
            for i, pg_im in enumerate(pdf_im_data):
                pg_im.save("%s/page-%i.jpg"%(fold_path, i))
        return fold_path
    
    def remove_unicode(self,x):
        return x.encode("ascii", "ignore").decode()
    
    def get_table_of_content(self):
        return self.doc.get_toc()
    
    def get_page_content(self, page_no):
        pg = self.doc.load_page(page_no)
        paras = pg.get_text('blocks')

        blocks = []
        for para in paras:
            para_content = re.sub(' +', ' ', para[4].replace('\n',' ').strip())
            blocks.append(para_content)
        return blocks
    
    def section_name_splitter(self, x):
        spliter = re.findall("[0-9].1.",x)[0]
        hh = x.split(f' {spliter} ')
        return [hh[0], spliter+' '+hh[1]]
    
    def section_name_merger(self, x: list):
        merged_string = f"{x[0]} {x[1]}"
        return merged_string

    def extract_page_data(self):
        '''
        Extract the raw texts of different categories from the passed pdf
        '''
        documents = self.doc
        
        page_blocks = {}
        for pg_no in range(documents.page_count):
            pg_content = documents.load_page(pg_no)
            
            paras = pg_content.get_text('blocks')
            
            blocks = []
            for para in paras:
                blocks.append(para[4].replace('\n',' ').strip())
            
            page_blocks[pg_no] = blocks
        
        return page_blocks
    
    def get_content_structure(self):
        temp = []
        sec_count = 0
        sub_sec = 0
        l = self.get_table_of_content()
        if len(l) == 0:
            l = self.get_table_of_content_ocr()
        for j in range(0,len(l)):
            tag = 'root'
            i = l[j]
            level, section_name, page = i[0], i[1].strip(), i[2]
            if level == 1:
                root_section_name = section_name
                sec_count = sec_count + 1
                sub_sec = 0
                try:
                    if l[j+1][0] > 1:
                        tag = "root_with_child"
                except:
                    pass
            if level>1:
                tag = 'child'
                sub_sec += 1 
                if sub_sec == 1:
                    section_text_name = f'{sec_count}. {root_section_name} {sec_count}.{sub_sec}. {section_name}'
                else:
                    section_text_name = f'{sec_count}.{sub_sec}. {section_name}'
            elif section_name == "References":
                section_text_name = f'{section_name}'
            else:
                section_text_name = f'{sec_count}. {section_name}'
            temp.append([section_text_name, page, tag])
        return temp
    
    
    def get_content_structure_working(self):
        temp = []
        sec_count = 0
        sub_sec = 0
        
        if self.extraction_mode == "auto":
            l = self.get_table_of_content()
            process_flag = "digital"
            if len(l) == 0:
                l = self.get_table_of_content_ocr_working()
                process_flag = "ocr"
        elif self.extraction_mode == 'digital':
            l = self.get_table_of_content()
            process_flag = "digital"
        elif self.extraction_mode == 'ocr':
            l = self.get_table_of_content_ocr_working()
            process_flag = "ocr"
            
        for j in range(0,len(l)):
            tag = 'root'
            i = l[j]
            level, section_name, page = i[0], i[1].strip(), i[2]
            if level == 1:
                root_section_name = section_name
                sec_count = sec_count + 1
                sub_sec = 0
                try:
                    if l[j+1][0] > 1:
                        tag = "root_with_child"
                except:
                    pass
            if level>1:
                tag = 'child'
                sub_sec += 1 
                section_text_name = f'{sec_count}.{sub_sec}. {section_name}'
            elif section_name == "References":
                section_text_name = f'{section_name}'
            else:
                section_text_name = f'{sec_count}. {section_name}'
            temp.append([section_text_name, page, tag])
        return process_flag, temp
    
    
    def get_table_of_content_ocr(self, image_fold_path = None, header_type = 'caps'):
        img_fold_path = self.save_page_images(image_fold_path = image_fold_path)
        
        pg_headers = []
        for i, pg in enumerate(self.doc):
            filename = f"{img_fold_path}/page-{str(i)}.jpg"
            files = {'my_file': (filename, open(filename, 'rb'))}

            response = requests.post(
                'http://20.83.24.160:8889/getLayout',
                files=files)
            headers = response.json()['header']
            
            if self.set_header_type is not None:
                header_type = self.set_header_type
                
            if header_type == 'caps':
                headers = [j for j in headers if j.isupper()]
                
            if len(headers) != 0:
                pg_content = self.get_page_content(i)
                header_pos_ind = {}
                for h in headers:
                    try:
                        header_pos_ind[h] = pg_content.index(h)
                    except:
                        for j, line in enumerate(pg_content):
                            if h in line:
                                header_pos_ind[h] = j
                                break
                headers_sorted = [k for k, v in sorted(header_pos_ind.items(), key=lambda item: item[1])]
                for h in headers_sorted:
                    pg_headers.append([1, h, i+1])
        return pg_headers
    
    
    def get_table_of_content_ocr_working(self, image_fold_path = None, header_type = 'caps'):
        img_fold_path = self.save_page_images(image_fold_path = image_fold_path)

        if os.path.exists(f"{img_fold_path}/header.h"):
            with open(f"{img_fold_path}/header.h", "rb") as f:
                pg_headers = pickle.load(f)
        else:
            pg_headers = []
            for i, pg in enumerate(self.doc):
                filename = f"{img_fold_path}/page-{str(i)}.jpg"
                files = {'my_file': (filename, open(filename, 'rb'))}

                response = requests.post(
                    'http://20.83.24.160:8889/getLayout',
                    files=files)
                headers = response.json()['header']
                
                headers = [i for i in headers if i != '']
                
                if self.set_header_type is not None:
                    header_type = self.set_header_type
                
                if header_type == 'caps':
                    headers = [j for j in headers if j.isupper()]

                if len(headers) != 0:
                    pg_content = self.get_page_content(i)
                    
                    #pg_content = [' '.join(pg_content)]
                    
                    line_headers = OrderedDict()
                    for j, line in enumerate(pg_content):
                        temp_line_header = []
                        for h in headers:
                            if h in line:
                                temp_line_header.append(h)
                        line_headers[line] = temp_line_header

                    line_headers = {k:v for k,v in line_headers.items() if len(v) != 0}

                    headers_sorted = []
                    for k, v in line_headers.items():
                        if len(v) >1:
                            v.sort(key=len, reverse=True) 
                            for it_ in v:
                                k = k.replace(it_, '_'.join(it_.split()))

                            k_split = k.split(" ")

                            index_dict = {}

                            for it_ in v:
                                try:
                                    index_dict[it_] = k_split.index('_'.join(it_.split()))
                                except:
                                    continue

                            index_dict_key_sorted = [k for k, v in sorted(index_dict.items(), key=lambda item: item[1])]
                            headers_sorted.extend(index_dict_key_sorted)
                        else:
                            headers_sorted.append(v[0])
                    for h in headers_sorted:
                        pg_headers.append([1, h, i+1])

            with open(f"{img_fold_path}/header.h","wb") as f:
                pickle.dump(pg_headers,f)
            
        return pg_headers
    
    
    def get_content_structure_filtered(self):
        _ , all_content_struc = self.get_content_structure_working()
        filtered_content_struc = [[i[0].encode("ascii", "ignore").decode(), i[1]] for i in all_content_struc] #if i[2]!= 'root_with_child']
        #filtered_content_struc = [[re.sub(r'[^\x00-\x7F]+',' ', i[0]), i[1]] for i in all_content_struc]        
        filtered_content_struc.append(['DUMMY',filtered_content_struc[-1][1]])
        return _ , filtered_content_struc
    
    
    def get_content_section_wise(self, extraction_mode = 'auto', set_header_type = None):
        
        if set_header_type is None:
            self.set_header_type = 'all'
        else:
            self.set_header_type = set_header_type
            
        self.extraction_mode = extraction_mode
        
        process_flag, ll = self.get_content_structure_filtered()
        
        print(ll)
        print(f"\n\nProcessing through : {process_flag}")
        if process_flag == "digital":
            all_sec_content = []
            j = 0
            sec_content = ''
            breaker = 3
            dic = {}
            
            try:
                while j < len(ll)-1:
                    sec_start_page_no, start_sec_name = ll[j][1], ll[j][0]
                    sec_end_page_no, end_sec_name = ll[j+1][1], ll[j+1][0]
                    flag = False
                    for i in range(sec_start_page_no, sec_end_page_no+1):
                        pg = self.doc.load_page(i-1)
                        paras = pg.get_text('blocks')

                        blocks = []
                        for para in paras:
                            blocks.append(para[4].replace('\n',' ').strip().encode("ascii", "ignore").decode())

                        if i != sec_end_page_no:
                            sec_content += ' '.join(blocks)
                        else:
                            try:
                                next_section_header_index = blocks.index(end_sec_name)
                                
                                till_pg_section = blocks[:next_section_header_index]
                                sec_content += ' '.join(till_pg_section)

                                next_sec_start_section = blocks[next_section_header_index:]
                                next_sec_start_content = ' '.join(next_sec_start_section)
                            except Exception as e:
                                #print(e)
                                #print(blocks, " ---- ", start_sec_name, " --- ",end_sec_name,">>>>>>>>>>>>>>>>> \n\n")
                                if end_sec_name != "References":
                                    new_ll = ll[:j+1]
                                    n_1 = ll[j+1][0]
                                    n_2 = ll[j+2][0]
                                    merged_section_name = pdf.section_name_merger([n_1, n_2])
                                    new_ll.append([merged_section_name, sec_end_page_no])
                                    new_ll.extend(ll[j+3:])
                                    ll = new_ll
                                else:
                                    ll[-2][1] += 1
                                flag = True
                                break

                    if flag == False:
                        dic[start_sec_name] = sec_content
                        #all_sec_content.append([start_sec_name, sec_content])
                        sec_content = next_sec_start_content
                        j += 1
                    else:
                        sec_content = ''
            except Exception as e:
                #print(e)
                pass
            return dic
        else:
            all_sec_content = []
            j = 0
            full_content = ''

            for pg_no in range(self.doc.page_count):
                full_content += ' '.join(self.get_page_content(pg_no))

            dic = {}
            for i, sec_pg in enumerate(ll):
                header = sec_pg[0]
                temp = full_content.split(header)
                if len(temp) == 1:
                    try:
                        number = re.findall("[0-9]+. ",header)[0]
                        #print(header,": ",number,"#####\n\n")
                        header_ = header.replace(number,'')
                        header_ = re.sub(' +', ' ',header_)
                    except Exception as e:
                        header_ = header
                    
                    try:
                        temp = full_content.split(header_)
                        first_por = temp[0]
                        second_por = temp[1]
                    except Exception as e:
                        #print(e)
                        pass
                else:
                    first_por = temp[0]
                    second_por = temp[1]

                if i > 0:
                    dic[prev_header_mem] = first_por
                prev_header_mem = header
                full_content = second_por
                
            return dic

# %%
class extract_section_for_all_pdf(pymupdf_extraction_utils):
    
    def __init__(self, pdf_folder_path):
        self.pdf_folder_path = pdf_folder_path
        
    def list_all_files_from_folder(self, path):
        all_pdfs = os.listdir(path)
        all_pdfs = [i for i in all_pdfs if i.endswith('.pdf')]
        pdf_id_name_dict = {i:all_pdfs[i] for i in range(0,len(all_pdfs))}
        return pdf_id_name_dict
    
    def extract_sectional_data(self):
        all_pdfs_to_process = self.list_all_files_from_folder(self.pdf_folder_path)

        temp = []
        for id_, pdf_file in all_pdfs_to_process.items():
            pdf = pymupdf_extraction_utils(self.pdf_folder_path+pdf_file)
            try:
                print(f"Processing for {pdf_file} ...")
                content = pdf.get_content_section_wise(extraction_mode="ocr", set_header_type='caps')
                temp.append([id_, pdf_file, content])
            except:
                print(f"Issue with {pdf_file} to process")
            print("\n\n=====================================\n\n")
        
        return pd.DataFrame(temp, columns=['id','pdf','data'])

# %%
gen = extract_section_for_all_pdf("../data/genai_poc/raw/AI_POC_47Papers_Nov06_SMTA/")

# %%
df_oct_47 = gen.extract_sectional_data()
# Out:
# Processing for EFFECT OF REFLOW TIME ON WETTING BEHAVIOUR, INTERFACIAL REACTION.pdf ...
# [['1. EXPERIMENTAL', 2], ['2. Shear test results', 4], ['3. CONCLUSION', 5], ['DUMMY', 5]]
#
#
# Processing through : ocr
#
#
# =====================================
#
#
# Processing for Predicting the Saturation of Solder Joint Cycles to Failure with Thermal Cycling Dwell Times.pdf ...
# [['1. ABSTRACT', 1], ['2. SATURATION CYCLES PHENOMENOLOGICAL', 5], ['3. PREDICTIVE SATURATION MODEL', 6], ['4. CONCLUSIONS', 8], ['5. ACKNOWLEDGEMENTS', 9], ['6. REFERENCES', 9], ['DUMMY', 9]]
#
#
# Processing through : ocr
#
#
# =====================================
#
#
# Processing for Qualitative Model Describing Hot Tear Above VIPPO and Numerous Other Design Elements.pdf ...
# [['1. QUALITATIVE MODEL DESCRIBING HOT TEAR ABOVE VIPPO AND NUMEROUS', 1], ['2. ABSTRACT', 1], ['3. INTRODUCTION', 1], ['4. MODEL FOR HOT TEAR AT INTERFACES', 2], ['5. DIRECTIONAL PHASE TRANSITIONS', 3], ['6. DIRECTIONAL PHASE TRANSITIONS', 4], ['7. LOAD', 5], ['8. CONCLUSION', 7], ['9. REFERENCES', 7], ['DUMMY', 7]]
#
#
# Processing through : ocr
#
#
# =====================================
#
#
# Processing for Edge Bonding as Viable Reinforcement for Solder Joints in High Reliability Applications.pdf ...
# [['1. Edge Bonding AS Viable Reinforcement for', 1], ['2. ABSTRACT', 1], ['3. INTRODUCTION', 1], ['4. EXPERIMENTAL DESCRIPTION', 2], ['5. RESULTS AND DISCUSSION', 3], ['6. CONCLUSION', 4], ['7. FUTURE WORKS', 4], ['8. ACKNOWLEDGEMENT', 4], ['9. REFERENCES', 4], ['10. APPENDIX A', 5], ['DUMMY', 5]]
#
#
# Processing through : ocr
#
#
# =====================================
#
#
# Processing for Control Of Spalling in SAC Pb-Free Solder Alloys When Used with a Ni Substrate.pdf ...
# [['1. ABSTRACT', 1], ['2. INTRODUCTION', 1], ['3. BACKGROUND', 1], ['4. Experimental Procedure', 2], ['5. Observations and Discussion', 2], ['6. CONCLUSION', 6], ['DUMMY', 6]]
#
#
# Processing through : ocr
#
#
# =====================================
#
#
# Processing for Identifying Causes of Wire Bond Pad Metal Lift-Off Failures in ENEPIG Deposits.pdf ...
# [['1. ABSTRACT', 1], ['2. INTRODUCTION', 1], ['3. METHODS AND MATERIALS', 2], ['4. RESULTS', 3], ['5. CONCLUSIONS', 5], ['6. REFERENCES', 5], ['DUMMY', 5]]
#
#
# Processing through : ocr
#
#
# =====================================
#
#
# Processing for Solder Joint Separation During Second Reflow Induced by VIPPO Structures Mechanism and Modeling Methodology Study.pdf ...
# [['1. ABSTRACT', 1], ['2. INTRODUCTION', 1], ['3. FAILURE PHENOMENON AND OBSERVATIONS', 1], ['4. JOINT SEPARATION MECHANISM STUDY', 3], ['5. MECHANISM MATERIAL AND DEFORMATION', 5], ['6. SUMMARY OF TESTING RESULTS AND', 6], ['7. MODELING APPROACH AND APPLICATION', 8], ['8. FUTURE WORK', 9], ['9. CONCLUSIONS', 9], ['10. REFERENCES', 10], ['DUMMY', 10]]
#
#
# Processing through : ocr
#
#
# =====================================
#
#
# Processing for SOLDER BALL JOINT RELIABILITY WITH ELECTROLESS NIPDAU PLATING.pdf ...
# [['1. ABSTRACT', 1], ['2. INTRODUCTION', 1], ['3. EXPERIMENTS', 1], ['4. RESULTS AND DISCUSSION', 2], ['5. CONCLUSION', 7], ['6. REFERENCES', 7], ['DUMMY', 7]]
#
#
# Processing through : ocr
#
#
# =====================================
#
#
# Processing for Comparing Optimizing Actual Solder Fatigue Life.pdf ...
# [['1. ABSTRACT', 1], ['2. INTRODUCTION', 1], ['3. SOLDER FATIGUE', 2], ['4. STRESS RELAXATION', 2], ['5. EXPERIMENTS', 3], ['6. CONCLUSIONS', 7], ['7. ACKNOWLEDGMENT', 7], ['8. REFERENCES', 7], ['DUMMY', 7]]
#
#
# Processing through : ocr
#
#
# =====================================
#
#
# Processing for Thermal Shock Testing of High-Reliability Solder Alloys.pdf ...
# [['1. ABSTRACT', 1], ['2. INTRODUCTION', 1], ['3. EXPERIMENTAL SETUP', 2], ['4. SUMMARY AND CONCLUSIONS', 7], ['5. ACKNOWLEDGEMENTS', 8], ['6. REFERENCES', 8], ['DUMMY', 8]]
#
#
# Processing through : ocr
#
#
# =====================================
#
#
# Processing for MECHANICAL FAILURES IN PB-FREE PROCESSING EVALUATING THE EFFECT OF PAD CRATER DEFECTS ON PROCESS STRAIN LIMITS FOR BGA DEVICES.pdf ...
# [['1. ABSTRACT', 1], ['2. INTRODUCTION', 1], ['3. EXPERIMENTAL DESIGN', 2], ['4. SAMPLE PREPARATION', 3], ['5. METTALURGY', 3], ['6. FLEXURAL TEST BENDING MODE', 4], ['7. TEST SETUP AND DATA COLLECTION', 4], ['8. RESULTS', 5], ['9. CONCLUSIONS', 6], ['10. FUTURE WORK', 6], ['11. ACKNOWLEDGMENTS', 6], ['DUMMY', 6]]
#
#
# Processing through : ocr
#
#
# =====================================
#
#
# Processing for Reliability Of Mixed Alloy Ball Grid Arrays Under Thermal Fatigue And Drop Shock Test.pdf ...
# [['1. RELIABILITY OF MIXED ALLOY BALL GRID ARRAYS UNDER THERMAL', 1], ['2. INTRODUCTION', 1], ['3. EXPERIMENTAL DETAILS', 2], ['4. RESULTS AND DISCUSSION', 3], ['5. CONCLUSIONS', 7], ['6. ACKNOWLEDGEMENT', 8], ['DUMMY', 8]]
#
#
# Processing through : ocr
#
#
# =====================================
#
#
# Processing for Thermal Fatigue of Quad Flat No-Lead and Chip Resistor Solder Joints Assembled with SnPb, SAC305, and SnBi Solders.pdf ...
# [['1. ABSTRACT', 1], ['2. INTRODUCTION', 1], ['3. EXPERIMENTAL', 3], ['4. RESULTS', 4], ['5. ION', 8], ['6. SUMMARY AND CONCLUSIONS', 8], ['7. ACKNOWLEDGEMENTS', 8], ['8. REFERENCES', 8], ['DUMMY', 8]]
#
#
# Processing through : ocr
#
#
# =====================================
#
#
# Processing for An Empirical Correlation to Estimate Solder Joint Reliability Acceleration Factors.pdf ...
# [['1. An Empirical Correlation to Estimate Solder Joint Reliability Acceleration Factors', 1], ['2. ABSTRACT', 1], ['3. INTRODUCTION', 1], ['4. HISTORICAL REVIEW OF SOLDER JOINT', 1], ['5. EMPIRICAL FIT FOR ACCELERATION FACTOR', 3], ['6. REGRESSION ANALYSIS TO IDENTIFY', 4], ['7. GRAPHICAL SOLUTION', 6], ['8. ACKNOWLEDGEMENTS', 6], ['9. REFERENCES', 6], ['DUMMY', 6]]
#
#
# Processing through : ocr
#
#
# =====================================
#
#
# Processing for High-Cycle Fatigue Test Development to Assess Pb-free Solder Joints.pdf ...
# [['1. ABSTRACT', 1], ['2. INTRODUCTION', 1], ['3. APPROACH', 3], ['4. PRELIMINARY RESULTS', 4], ['5. PRELIMINARY CONCLUSIONS', 8], ['6. FUTURE WORK', 8], ['7. ACKNOWLEDGEMENTS', 8], ['8. WORKS CITED', 9], ['DUMMY', 9]]
#
#
# Processing through : ocr
#
#
# =====================================
#
#
# Processing for Reliability of Different Solder Joint Alloys in Thermal Cycling and Drop Shock Tests.pdf ...
# [['1. ABSTRACT', 1], ['2. INTRODUCTION', 1], ['3. EXPERIMENTAL PROCEDURE', 2], ['4. CONCLUSION', 9], ['5. REFERENCES', 9], ['DUMMY', 9]]
#
#
# Processing through : ocr
#
#
# =====================================
#
#
# Processing for INVESTIGATION OF SOLDER JOINT RELIABILITY.pdf ...
# [['1. INVESTIGATION OF SOLDER JOINT RELIABILITY', 1], ['2. ABSTRACT', 1], ['3. INTRODUCTION', 1], ['4. RESULTS', 4], ['DUMMY', 4]]
#
#
# Processing through : ocr
#
#
# =====================================
#
#
# Processing for Electronic Hardware in Space - Failure Avoidance is Critical to Missions Success.pdf ...
# [['1. ABSTRACT', 1], ['2. INTRODUCTION', 1], ['3. ECSS ASSEMBLY VERIFICATION', 1], ['4. RETURN OF EXPERIENCE FROM THE ECSS', 3], ['5. USE OF COMMERCIAL PARTS', 5], ['6. CONCLUSION', 5], ['7. REFERENCES', 5], ['DUMMY', 5]]
#
#
# Processing through : ocr
#
#
# =====================================
#
#
# Processing for Propensity for FCBGA Chip-UF and Substrate-UF Interface Delamination under Monotonic and Fatigue Loads in Automotive Environments.pdf ...
# [['1. ABSTRACT', 1], ['2. INTRODUCTION', 1], ['3. TEST VEHICLES', 2], ['4. SUMMARY AND CONCLUSIONS', 10], ['5. ACKNOWLEDGMENTS', 10], ['6. REFERENCES', 10], ['DUMMY', 10]]
#
#
# Processing through : ocr
#
#
# =====================================
#
#
# Processing for Via-In-Pad Plated Over (VIPPO) Design Considerations for the Mitigation of Unique Solder Separation Failure Mode.pdf ...
# [['1. ABSTRACT', 1], ['2. INTRODUCTION', 1], ['3. FAILURE MODE AND HISTORY', 2], ['4. FAILURE MECHANISM', 3], ['5. EVALUATION PLAN', 4], ['6. TEST VEHICLES', 4], ['7. RESULTS AND DISCUSSION', 5], ['8. DESIGN GUIDELINES', 6], ['9. SUMMARY AND CONCLUSIONS', 6], ['10. FUTURE WORK', 7], ['11. ACKNOWLEDGEMENTS', 7], ['12. REFERENCES', 7], ['DUMMY', 7]]
#
#
# Processing through : ocr
#
#
# =====================================
#
#
# Processing for Isothermal Fatigue of High Temperature Solder Joints.pdf ...
# [['1. ISOTHERMAL FATIGUE OF HIGH TEMPERATURE SOLDER JOINTS', 1], ['2. ABSTRACT', 1], ['3. INTRODUCTION', 1], ['4. EXPERIMENTAL', 1], ['5. RESULTS', 3], ['6. DISCUSSION', 6], ['7. CONCLUSION', 7], ['8. ACKNOWLEDGEMENTS', 8], ['9. REFERENCES', 8], ['10. BIOGRAPHY', 8], ['DUMMY', 8]]
#
#
# Processing through : ocr
#
#
# =====================================
#
#
# Processing for EFFECT OF PROCESS VARIATIONS ON SOLDER JOINT RELIABILITY FOR NICKEL-BASED SURFACE FINISHES.pdf ...
# [['1. EFFECT OF PROCESS VARIATIONS ON SOLDER JOINT RELIABILITY FOR', 1], ['2. ABSTRACT', 1], ['3. BACKGROUND', 1], ['4. DESCRIPTION OF INVESTIGATIONS', 2], ['5. TESTING RESULTS', 4], ['6. ACKNOWLEDGEMENTS', 7], ['DUMMY', 7]]
#
#
# Processing through : ocr
#
#
# =====================================
#
#
# Processing for Effect of Voids on Thermo-Mechanical Reliability of Solder Joints.pdf ...
# [['1. ABSTRACT', 1], ['2. INTRODUCTION', 1], ['3. VOIDS AND CRACKS', 1], ['4. RELATION BETWEEN SOLDER JOINT THERMAL', 4], ['5. SUMMARY', 6], ['6. ACKNOWLEDGEMENTS', 7], ['7. REFERENCES', 7], ['DUMMY', 7]]
#
#
# Processing through : ocr
#
#
# =====================================
#
#
# Processing for Influence of Surface Finishes and Solder Alloys on Solder Ball Joint Reliability.pdf ...
# [['1. ABSTRACT', 1], ['2. INTRODUCTION', 1], ['3. EXPERIMENT', 2], ['4. RESULTS AND DISCUSSION', 3], ['5. CONCLUSION', 14], ['DUMMY', 14]]
#
#
# Processing through : ocr
#
#
# =====================================
#
#
# Processing for A NICKEL-PALLADIUM-GOLD IC LEAD FINISH AND THE POTENTIAL.pdf ...
# [['1. ABSTRACT', 1], ['2. INTRODUCTION', 1], ['3. Solder Paste and Reflow Profile', 2], ['4. Board Mount Equipment And Procedure', 2], ['5. Theoretical Au Content Calculations', 2], ['6. RESULTS', 3], ['7. VISUAL APPEARANCE', 3], ['8. Lead Pull Test', 3], ['9. Lead Pull Data', 4], ['10. Observations from Lead Pull Results', 4], ['11. Summary of Cross Section Analysis', 9], ['12. GMENTS', 9], ['DUMMY', 9]]
#
#
# Processing through : ocr
# =====================================
#
#
# Processing for CRACK GROWTH RATE MEASUREMENT AND ANALYSIS FOR WLCSP Sn-Ag-Cu SOLDER JOINTS.pdf ...
# [['1. CRACK GROWTH RATE MEASUREMENT AND ANALYSIS FOR WLCSP', 1], ['2. ABSTRACT', 1], ['3. INTRODUCTION', 1], ['4. TEST SAMPLE PREPARATION', 1], ['5. TEST SAMPLE CHARACTERIZATION', 1], ['6. TEST PROCEDURE', 2], ['7. MODELING', 2], ['8. RESULTS', 3], ['9. MEASUREMENT OF CRACK AREA', 3], ['10. VARIATION IN MEASUREMENTS', 4], ['11. MICROSTRUCTURAL EVALUATION', 5], ['12. CONCLUSIONS', 6], ['13. ACKNOWLEDGEMENTS', 7], ['14. REFERENCES', 7], ['DUMMY', 7]]
#
#
# Processing through : ocr
#
#
# =====================================
#
#
# Processing for PROCESS CAPABILITY, WETTING BEHAVIOR AND TEMPERATURE DEPENDENT SHEAR STRENGTH OF ALTERNATIVE LEAD FREE SOLDER JOINTS.pdf ...
# [['1. ABSTRACT', 1], ['2. INTRODUCTION', 1], ['3. EXPERIMENTS', 2], ['4. RESULTS AND DISCUSSION', 2], ['5. REFERENCES', 6], ['DUMMY', 6]]
#
#
# Processing through : ocr
#
#
# =====================================
#
#
# Processing for High-Reliability Lead-free Solder for Electronics in Automotive Applications.pdf ...
# [['1. ABSTRACT', 1], ['2. INTRODUCTION', 1], ['3. RESULTS AND DISCUSSION', 2], ['4. CONCLUSION', 5], ['5. REFERENCES', 5], ['DUMMY', 5]]
#
#
# Processing through : ocr
#
#
# =====================================
#
#
# Processing for Thermal Fatigue Reliability of a 1206 Chip Resistor with High-Performance Pb-Free Solder Alloys.pdf ...
# [['1. ABSTRACT', 1], ['2. INTRODUCTION', 1], ['3. EXPERIMENTAL', 2], ['4. RESULTS', 4], ['5. ACKNOWLEDGEMENTS', 7], ['6. REFERENCES', 8], ['DUMMY', 8]]
#
#
# Processing through : ocr
#
#
# =====================================
#
#
# Processing for The Thermal Cycling Performance of Hybrid Low Temperature Solder Joints Assembled at Different Peak Reflow Temperatures.pdf ...
# [['1. ABSTRACT', 1], ['2. INTRODUCTION', 1], ['3. EXPERIMENTAL', 2], ['4. SUMMAR', 11], ['5. ACKNOWLEDGEMENTS', 12], ['6. REFERENCES', 12], ['DUMMY', 12]]
#
#
# Processing through : ocr
#
#
# =====================================
#
#
# Processing for EFFECT OF ISOTHERMAL PRECONDITIONING ON THERMAL.pdf ...
# [['1. EFFECT OF ISOTHERMAL PRECONDITIONING ON THERMAL', 1], ['2. ABSTRACT', 1], ['3. INTRODUCTION', 1], ['4. EXPERIMENTAL', 1], ['5. RESULTS AND DISCUSSION', 3], ['6. SUGGESTIONS FOR FUTURE WORK', 10], ['7. SUMMARY AND CONCLUSIONS', 10], ['8. ACKNOWLEDGMENTS', 10], ['9. REFERENCES', 10], ['10. APPENDIX', 12], ['DUMMY', 12]]
#
#
# Processing through : ocr
#
#
# =====================================
#
#
# Processing for The Impact of the Gold Layer Thickness on Layer Properties, Reliability and Solder Wetting Performance of an ENIG Finish.pdf ...
# [['1. ABSTRACT', 1], ['2. INTRODUCTION', 1], ['3. IMMERSION GOLD LAYER PROPERTIES AND', 1], ['4. SEM imaging', 2], ['5. Solderability and solder joint reliability', 2], ['6. Results', 2], ['7. SUMMARY AND CONCLUSION', 4], ['8. REFERENCES', 5], ['DUMMY', 5]]
#
#
# Processing through : ocr
#
#
# =====================================
#
#
# Processing for Influence of a New Abnormal CuNi6Sn5 NiCu3Sn4 Layer Growth at Temperatures Above 175C in Tin Silver Based Lead-Free Solder Joints.pdf ...
# [['1. ABSTRACT', 1], ['2. INTRODUCTION', 1], ['3. EXPERIMENTAL PROCEDURE', 2], ['4. EXPERIMENTAL RESULTS', 2], ['5. DISCUSSION', 5], ['6. CONCLUSIONS', 7], ['7. SUMMARY', 7], ['8. REFERENCES', 8], ['9. APPENDIX', 9], ['DUMMY', 9]]
#
#
# Processing through : ocr
#
#
# =====================================
#
#
# Processing for Gold Embrittlement in Leadfree Solder.pdf ...
# [['1. INTRODUCTION', 1], ['2. TEST SAMPLES', 1], ['3. DISCUSSION', 10], ['4. CONCLUSION', 11], ['5. ACKNOWLEDGEMENTS', 12], ['DUMMY', 12]]
#
#
# Processing through : ocr
#
#
# =====================================
#
#
# Processing for Solder-Joint Reliability of a 0.65mm Pitch Molded Array Package for Automotive Applications.pdf ...
# [['1. ABSTRACT', 1], ['2. INTRODUCTION', 1], ['3. EXPERIMENTAL METHODS', 1], ['4. EXPERIMENTAL RESULTS', 5], ['5. CONCLUSIONS', 8], ['6. ACKNOWLEDGEMENTS', 9], ['7. REFERENCES', 9], ['DUMMY', 9]]
#
#
# Processing through : ocr
#
#
# =====================================
#
#
# Processing for FAILURE MECHANISM OF SAC 305 AND SAC 405 IN HARSH ENVIRONMENTS AND INFLUENCE OF BOARD DEFECTS INCLUDING BLACK PAD.pdf ...
# [['1. FAILURE MECHANISM OF SAC 305 AND SAC 405 IN HARSH ENVIRONMENTS', 1], ['2. ABSTRACT', 1], ['3. INTRODUCTION', 1], ['4. EXPERIMENTAL', 1], ['5. RESULTS AND DISCUSSION', 3], ['6. CONCLUSIONS', 11], ['7. ACKNOWLEDGEMENTS', 11], ['8. REFERENCES', 11], ['DUMMY', 11]]
#
#
# Processing through : ocr
#
#
# =====================================
#
#
# Processing for Characterization of Soldered Plated Through Holes (PTHs) and Gold Embrittlement Conditions.pdf ...
# [['1. ABSTRACT', 1], ['2. BACKGROUND', 1], ['3. OBJECTIVE', 2], ['4. TEST PROCEDURES', 2], ['5. Test Vehicle', 2], ['6. Test Vehicle Assembly', 2], ['7. TEST RESULTS', 3], ['8. DISCUSSION', 4], ['9. CONCLUSIONS', 5], ['10. ACKNOWLEDGEMENTS', 5], ['11. REFERENCES', 5], ['DUMMY', 5]]
#
#
# Processing through : ocr
#
#
# =====================================
#
#
# Processing for Reliability Degradation of SAC105 and SAC305 BGA Packages Under Long-Term, High Temperature Aging.pdf ...
# [['1. NOMENCLATURE', 1], ['2. INTRODUCTION', 1], ['3. EXPERIMENT', 2], ['4. RESULT AND DISCUSSION', 2], ['5. CONCLUSIONS', 7], ['DUMMY', 7]]
#
#
# Processing through : ocr
#
#
# =====================================
#
#
# Processing for Component and Printed Wiring Board Finish Effects on QFN Solder Joint Formation.pdf ...
# [['1. COMPO', 1], ['2. ABSTRACT', 1], ['3. INTRODUCTION', 1], ['4. EXPERIMENTAL PROCEDURE', 2], ['5. Sample configuration', 2], ['6. RESULTS AND DISCUSSION', 3], ['7. Void Formation', 4], ['8. CONCLUSIONS', 6], ['9. FUTURE WORK', 7], ['10. ACKNOWLEDGEMENTS', 7], ['11. REFERENCES', 7], ['DUMMY', 7]]
#
#
# Processing through : ocr
#
#
# =====================================

# %%
gen = extract_section_for_all_pdf("../data/genai_poc/raw/AI_POC_Papers_Dec11_SMTA/")

# %%
df_dec_30 = gen.extract_sectional_data()
# Out:
# Processing for IPC-CC-830B vs The Real World Part Factors Influencing the Tendency for A Conformal Coating to Crack During Thermal Shock Cycling.pdf ...
# [['1. ABSTRACT', 1], ['2. INTRODUCTION', 1], ['DUMMY', 1]]
#
#
# Processing through : ocr
#
#
# =====================================
#
#
# Processing for Evaluations of High Reliability Lead-Free Solder Paste.pdf ...
# [['1. ABSTRACT', 1], ['2. EXPERIMENTAL', 1], ['3. RESULTS AND DISCUSSION', 4], ['4. EPMA', 5], ['5. EPMA', 5], ['6. CONCLUSIONS', 10], ['DUMMY', 10]]
#
#
# Processing through : ocr
#
#
# =====================================
#
#
# Processing for Assessment of the Behavior of High Reliability Solder Alloys in Accelerated Thermal Testing.pdf ...
# [['1. ASSESSMENT OF THE BEHAVIOR OF HIGH RELIABILITY SOLDER', 1], ['2. ABSTRACT', 1], ['3. INTRODUCTION', 1], ['4. RESULTS AND DISCUSSION', 3], ['5. CONCLUSION', 9], ['DUMMY', 9]]
#
#
# Processing through : ocr
#
#
# =====================================
#
#
# Processing for HnP Defects by Emulating The Gap Between BGA and PCB During Reflow.pdf ...
# [['1. ABSTRACT', 1], ['2. NTRODUCTION', 1], ['3. CONCLUSION', 7], ['4. REFERENCES', 7], ['DUMMY', 7]]
#
#
# Processing through : ocr
#
#
# =====================================
#
#
# Processing for Reliability Study of Doped Lead Free Solder Paste Alloys by Thermal Cycling Testing.pdf ...
# [['1. RELIABILITY STUDY OF DOPED LEAD FREE SOLDER PASTE ALLOYS BY', 1], ['2. INTRODUCTION', 1], ['3. EXPERIMENT SETUP', 3], ['4. DATA ACQUISITION SYSTEM', 3], ['5. SAMPLE PREPARATION', 3], ['6. TEST DESCRIPTION', 3], ['7. REFERENCES', 6], ['DUMMY', 6]]
#
#
# Processing through : ocr
#
#
# =====================================
#
#
# Processing for Solder Joint Separation During Second Reflow Induced by VIPPO Structures Mechanism and Modeling Methodology Study.pdf ...
# [['1. ABSTRACT', 1], ['2. TRODUCTION', 1], ['3. AILURE PHENO', 1], ['4. JOINT SEPARATION MECHANISM STUDY', 3], ['5. MECHANISM MATERIAL AND DEFORMATION', 5], ['6. SUMMARY OF TESTING RESULTS AND', 6], ['7. MODELING APPROACH AND APPLICATION', 8], ['8. FUTURE WORK', 9], ['9. CONCLUSIONS', 9], ['10. REFERENCES', 10], ['DUMMY', 10]]
#
#
# Processing through : ocr
#
#
# =====================================
#
#
# Processing for Innovative BGA Defect Detection Method for Transient Discontinuity.pdf ...
# [['1. INNOVATIVE BGA DEFECT DETECTION METHOD', 1], ['2. ABSTRACT', 1], ['3. INTRODUCTION', 1], ['4. MOTIVATION AND INITIATION', 1], ['5. CONCEPT OF THE METHODOLOGY', 3], ['6. EXPERIMENTAL APPARATUS AND PROCESS', 3], ['7. RESISTENCE TEST RESULTS', 4], ['8. SUMMARY', 5], ['9. FUTURE WORK', 5], ['10. ACKNOWLEDGEMENT', 5], ['11. REFERENCES', 5], ['DUMMY', 5]]
#
#
# Processing through : ocr
#
#
# =====================================
#
#
# Processing for Package-On-Package (PoP) Solder Short FA Technique.pdf ...
# [['1. ABSTRACT', 1], ['2. INTRODUCTION', 1], ['3. CONFIRMATION METHODOLOGY', 6], ['4. CONCLUSION', 6], ['5. FUTURE WORK', 6], ['6. ACKOWLEDGEMENTS', 6], ['7. REFERENCES', 6], ['DUMMY', 6]]
#
#
# Processing through : ocr
#
#
# =====================================
#
#
# Processing for Assembly and Failure Analysis of WLP with 0.3 mm Pitch and Smaller.pdf ...
# [['1. ASSEMBLY AND FAILURE ANALYSIS', 1], ['2. ABSTRACT', 1], ['3. TEST VEHICLES', 1], ['4. PCB LAND PATTREN DESIGN', 1], ['5. PRINTING PROCESS', 2], ['6. PICK AND PLACE', 4], ['7. FLUX DIPPING PROCESS', 4], ['8. REFLOW PROCESS', 5], ['9. BOARD ASSEMBLY', 5], ['10. FAILURE ANALYSIS METHODS', 5], ['11. COMMON', 7], ['12. CONCLUSION', 9], ['13. REFERENCES', 9], ['DUMMY', 9]]
#
#
# Processing through : ocr
#
#
# =====================================
#
#
# Processing for Protocol Development for Testing Solder Reliability in Combined Environments.pdf ...
# [['1. PROTOCOL DEVELOPMENT FOR TESTING SOLDER RELIABILITY IN', 1], ['2. ABSTRACT', 1], ['3. INTRODUCTION', 1], ['4. LITERATURE REVIEW', 1], ['5. EXPERIMENTAL', 2], ['6. PHASE 1A TESTING', 2], ['7. TEST METHOD', 4], ['8. TEST RESULTS', 5], ['9. CONCLUSIONS', 7], ['10. FUTURE WORK', 8], ['11. ACKNOWLEDGEMENTS', 8], ['12. REFERENCES', 8], ['DUMMY', 8]]
#
#
# Processing through : ocr
#
#
# =====================================
#
#
# Processing for Reliability Assessment of Micro-Via Stacking Configuration in FCPBGA using FEM.pdf ...
# [['1. NTRODUCTION', 1], ['2. MODELING RESULS', 3], ['3. SUMMARY AND CONCLUSION', 6], ['4. REFERENCES', 6], ['DUMMY', 6]]
#
#
# Processing through : ocr
#
#
# =====================================
#
#
# Processing for The Influence of Die Size and Distance From Neutral Point on the Thermal Fatigue Reliability of a Chip Array BGA.pdf ...
# [['1. THE INFLUENCE OF DIE SIZE AND DISTANCE FROM NEUTRAL POINT ON', 1], ['2. ABSTRACT', 1], ['3. INTRODUCTION', 1], ['4. EXPERIMENTAL', 2], ['5. DISCUSSION', 7], ['6. FUTURE WORK', 8], ['7. SUMMARY', 8], ['8. ACKNOWLEDGEMENTS', 9], ['9. REFERENCES', 9], ['DUMMY', 9]]
#
#
# Processing through : ocr
#
#
# =====================================
#
#
# Processing for Case Study - Head in Pillow Defect on a Plastic Ball Grid Array.pdf ...
# [['1. ABSTRACT', 1], ['2. BACKGROUND', 1], ['3. PROBLEM STATEMENT', 2], ['4. INVESTIGATION', 2], ['5. CONCLUSIONS', 7], ['6. RECOMMENDATIONS', 7], ['7. ACKNOWLEDGEMENTS', 7], ['DUMMY', 7]]
#
#
# Processing through : ocr
#
#
# =====================================
#
#
# Processing for Acceleration Life Comparison of Solder Joint with Temperature Deviation under Thermal Cycling.pdf ...
# [['1. ACCELERATION LIFE COMPARISON OF SOLDER JOINT WITH', 1], ['2. ABSTRACT', 1], ['3. EXPERIMETNAL PROCEDURE', 1], ['4. RESULTS AND DISCUSSION', 2], ['5. CONCLUSIONS', 4], ['6. REFERENCES', 4], ['DUMMY', 4]]
#
#
# Processing through : ocr
#
#
# =====================================
#
#
# Processing for Crack Paths and Fracture Loads of BGA Solder Joints under Bending as a Function of Strain Rate and Mode Ratio.pdf ...
# [['1. CRACK PATHS AND FRACTURE LOADS OF BGA SOLDER JOINTS', 1], ['2. ABSTRACT', 1], ['3. CONCLUSIONS', 4], ['4. ACKNOWLEDGEMENTS', 5], ['5. REFERENCES', 5], ['DUMMY', 5]]
#
#
# Processing through : ocr
#
#
# =====================================
#
#
# Processing for Increased Reliability of Quad Flat No Lead (QFN) Wettable Flank Connections by Immersion Tin Plating.pdf ...
# [['1. ABSTRACT', 1], ['2. INTRODUCTION', 1], ['3. SOLDERING TESTING AND IMC FORMATION', 2], ['4. PLATING IMPACT ON ELECTROLYTIG TIN', 4], ['5. WHISKER MITIGATION OF IMMERSION TIN', 4], ['6. SUMMARY AND CONCLUSION', 5], ['7. REFERENCES', 6], ['DUMMY', 6]]
#
#
# Processing through : ocr
#
#
# =====================================
#
#
# Processing for Effect Of Variation In The Reflow Profile On The Microstructure Of Near Eutectic SnAgCu Alloys.pdf ...
# [['1. EFFECT OF VARIATION IN THE REFLOW PROFILE ON THE', 1], ['2. INTRODUCTION', 1], ['3. RESULTS', 2], ['4. CONCLUSION', 6], ['5. ACKNOWLEDGEMENTS', 6], ['6. REFERENCES', 6], ['DUMMY', 6]]
#
#
# Processing through : ocr
#
#
# =====================================
#
#
# Processing for A Modified Coffin-Manson Methodology for Predicting Solder Joint Life in Eutectic Tin-Lead and Lead-Free Assemblies.pdf ...
# [['1. ABSTRACT', 1], ['2. MODEL DEVELOPMENT', 1], ['3. LIFE PREDICTION MODELS', 8], ['4. MODEL VALIDATION', 10], ['5. CONCLUSIONS', 12], ['6. REFERENCES', 13], ['DUMMY', 13]]
#
#
# Processing through : ocr
#
#
# =====================================
#
#
# Processing for Machine Learning for Predicting PCBA Failures under Humidity Conditions.pdf ...
# [['1. MACHINE LEARNING FOR PREDICTING PCBA', 1], ['2. ABSTRACT', 1], ['3. OVERALL DISCUSSION AND CONCLUSION', 2], ['4. REFERENCE', 3], ['DUMMY', 3]]
#
#
# Processing through : ocr
#
#
# =====================================
#
#
# Processing for Component Warpage Issues with Measurement and Standardization.pdf ...
# [['1. ABSTRACT', 1], ['2. WARPAGE MEASUREMENT', 1], ['3. WARPAGE CASE STUDIES', 2], ['4. DISCUSSION', 3], ['5. CONCLUSION', 5], ['DUMMY', 5]]
#
#
# Processing through : ocr
#
#
# =====================================
#
#
# Processing for Multi-Axis Loading Effect on Edgebond and Cornerfilled WLCSP Thermal Cycling Performance.pdf ...
# [['1. ABSTRACT', 1], ['2. INTRODUCTION', 1], ['3. RESULTS AND DISCUSSION', 3], ['4. CONCLUSION', 7], ['5. ACKNOWLEDGEMENTS', 7], ['6. REFERENCES', 7], ['DUMMY', 7]]
#
#
# Processing through : ocr
#
#
# =====================================
#
#
# Processing for Reliability Improvement Of Cu-Wire Bonded Lead Frame Package For Automotive Applications.pdf ...
# [['1. ABSTRACT', 1], ['2. INTRODUCTION', 1], ['3. EXPERIMENTAL', 4], ['4. PACKAGE RELIABILITY RESULT', 6], ['5. DISCUSSIONS', 6], ['6. CONCLUSION', 7], ['7. ACKNOWLEDGEMENTS', 7], ['8. REFERENCES', 7], ['DUMMY', 7]]
#
#
# Processing through : ocr
#
#
# =====================================
#
#
# Processing for Fill the Void.pdf ...
# [['1. ABSTRACT', 1], ['2. RESULTS', 3], ['3. CONCLUSIONS', 7], ['4. FUTURE WORK', 7], ['5. REFERENCES', 7], ['DUMMY', 7]]
#
#
# Processing through : ocr
#
#
# =====================================
#
#
# Processing for Board Level Reliability Comparison of BGA and LGA Packages Mounted to an LGA Footprint Motherboard.pdf ...
# [['1. BOARD LEVEL RELIABILITY COMPARISON OF BGA AND LGA', 1], ['2. ABSTRACT', 1], ['3. INTRODUCTION', 1], ['4. TEST BOARD ASSEMBLY', 1], ['5. SMT RESULTS', 3], ['6. THERMAL SHOCK TESTING', 4], ['7. THERMAL SHOCK RESULTS', 6], ['8. FINITE ELEMENT ANALYSIS OF THERMAL', 7], ['9. DROP TEST', 8], ['10. CONCLUSIONS', 9], ['11. REFERENCES', 9], ['DUMMY', 9]]
#
#
# Processing through : ocr
#
#
# =====================================
#
#
# Processing for Influence of Microalloying Elements on Reliability of SnAgCu Solder Joints.pdf ...
# [['1. INFLUENCE OF MICROALLOYING ELEMENTS ON', 1], ['2. INTRODUCTION', 1], ['3. RESULTS AND DISSCUSSION', 4], ['4. CONCLUSIONS', 8], ['DUMMY', 8]]
#
#
# Processing through : ocr
#
#
# =====================================
#
#
# Processing for Effects of Long-Term Aging on SnAgCu Solder Joints Reliability in Mechanical Cycling Fatigue.pdf ...
# [['1. ABSTRACT', 1], ['2. INTRODUCTION', 1], ['3. EXPERIMENTAL SETUP', 2], ['4. EXPERIMENTAL PROCEDURE', 2], ['5. RESULTS AND DISCUSSION', 3], ['6. SUMMARY AND CONCLUSION', 6], ['7. REFERENCES', 6], ['DUMMY', 6]]
#
#
# Processing through : ocr
#
#
# =====================================
#
#
# Processing for Intermetallic Compound Analyses Provide Interfacial Reliability for Solder Connections in Electronics.pdf ...
# [['1. ABSTRACT', 1], ['2. INTRODUCTION', 1], ['3. METHODS AND PROCEDURES', 2], ['4. RESULTS', 4], ['5. CONCLUSION', 7], ['6. ACKNOWLEDGEMENT', 7], ['7. REFERENCES', 7], ['DUMMY', 7]]
#
#
# Processing through : ocr
#
#
# =====================================
#
#
# Processing for Analysis of the Root Cause for Solder Joint Cracking.pdf ...
# [['1. ANALYSIS OF THE ROOT CAUSE FOR SOLDER JOINT CRACKING', 1], ['2. ABSTRACT', 1], ['3. INTRODUCTION', 1], ['4. MORPHOLOGICAL ANALYSIS', 1], ['5. STRAIN MONITORING ANALYSIS', 2], ['6. FINITE ELEMENT SIMULATION ANALYSIS', 2], ['7. OVERALL ANALYSIS', 4], ['8. CONCLUSION AND IMPROVEMENT', 5], ['9. REFERENCES', 6], ['DUMMY', 6]]
#
#
# Processing through : ocr
# =====================================
#
#
# Processing for Degradation of Leadfree Solder Materials Subjected to Isothermal Aging With Use of the CABGA208 Package.pdf ...
# [['1. DEGRADATION OF LEADFREE SOLDER MATERIALS SUBJECTED', 1], ['2. ABSTRACT', 1], ['3. INTRODUCTION', 1], ['4. TEST VEHICLE', 2], ['5. ISOTHERMAL TESTING PROCESS', 2], ['6. CONCLUSION', 5], ['7. REFERENCES', 5], ['DUMMY', 5]]
#
#
# Processing through : ocr
#
#
# =====================================
#
#
# Processing for Microstructure of Weak-Micro-Via and its Failure Prevention.pdf ...
# [['1. ABSTRACT', 1], ['2. EXPERIMENTAL', 1], ['3. RESULTS', 2], ['4. CONCLUSION', 6], ['5. ACKNOWLEDGEMENTS', 6], ['6. REFERENCE', 6], ['DUMMY', 6]]
#
#
# Processing through : ocr
#
#
# =====================================

# %%
df_dec_30.shape, df_oct_47.shape
# Out:
# ((30, 3), (39, 3))

# %%
df = pd.concat([df_dec_30, df_oct_47], ignore_index=True)

# %%
df.reset_index(inplace=True)

# %%
df = df.drop('id',axis=1).rename(columns={'index':'id'})

# %%
df_grpd = df.groupby(['id'])

# %%
def grpd_func(x):
    temp_data = x['data'].values.tolist()[0]
    data_values = []
    i = 0
    for k,v in temp_data.items():
        data_values.append([i, k, v])
        i+= 1
    return pd.DataFrame(data_values, columns=['section_id','section','content'])

# %%
df_sub = df_grpd.apply(lambda x: grpd_func(x)).reset_index().drop("level_1",axis=1)

# %%
df_extended = df[['id','pdf']].merge(df_sub, on = 'id', how = 'inner')

# %%
df_extended
# Out:
#      id                                                pdf  section_id  \
# 0     0  IPC-CC-830B vs The Real World Part Factors Inf...           0
# 1     0  IPC-CC-830B vs The Real World Part Factors Inf...           1
# 2     1  Evaluations of High Reliability Lead-Free Sold...           0
# 3     1  Evaluations of High Reliability Lead-Free Sold...           1
# 4     1  Evaluations of High Reliability Lead-Free Sold...           2
# ..   ..                                                ...         ...
# 497  68  Component and Printed Wiring Board Finish Effe...           6
# 498  68  Component and Printed Wiring Board Finish Effe...           7
# 499  68  Component and Printed Wiring Board Finish Effe...           8
# 500  68  Component and Printed Wiring Board Finish Effe...           9
# 501  68  Component and Printed Wiring Board Finish Effe...          10
#
#                        section  \
# 0                  1. ABSTRACT
# 1              2. INTRODUCTION
# 2                  1. ABSTRACT
# 3              2. EXPERIMENTAL
# 4    3. RESULTS AND DISCUSSION
# ..                         ...
# 497          7. Void Formation
# 498             8. CONCLUSIONS
# 499             9. FUTURE WORK
# 500       10. ACKNOWLEDGEMENTS
# 501             11. REFERENCES
#
#                                                content
# 0     As electronics continue to become ever more d...
# 1     With the increased adoption of electronics in...
# 2     In recent years there has been an increased d...
# 3     Alloy Properties Testing was done on a develo...
# 4     Melting Point The melting point of the HR6A a...
# ..                                                 ...
# 497   Typical X-ray results showing the amount of v...
# 498   Finish effects on QFN thermal pad solder join...
# 499   Possible future work will be to evaluate addi...
# 500   The author would like to acknowledge L3Harris...
# 501   [1] R. Ghaffarian, "Body of Knowledge (BOK) f...
#
# [502 rows x 5 columns]

# %%
df_extended['context'] = df_extended[['section','content']].apply(lambda x: x[0]+" \n\n"+x[1], axis=1)

# %%
df_extended.to_pickle("../data/genai_poc/processed/AI_POC_pdf_extracted_sectional_data_oct_dec.pkl")
